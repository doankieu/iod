# %%
import pandas as pd
import seaborn as sns

# %%
football = pd.read_csv('/Users/linhvien/Downloads/EPL_20_21.csv')

# %%
football.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards
# ...

# %%
football[football.Goals>0].groupby(by = ["Club"]).agg({"Name":"count"}).sort_values(by="Name")
# Out:
#                          Name
# Club
# Sheffield United            9
# Everton                    10
# West Bromwich Albion       11
# Aston Villa                12
# Burnley                    12
# Tottenham Hotspur          12
# Fulham                     12
# Southampton                12
# Leeds United               13
# Crystal Palace             14
# Arsenal                    15
# Newcastle United           15
# Leicester City             15
# West Ham United            15
# Brighton                   15
# Wolverhampton Wanderers    15
# Manchester City            16
# Liverpool FC               16
# Chelsea                    16
# Manchester United          16

# %%
football.groupby(by = ["Club"])["xG"].sum()
# Out:
# Club
# Arsenal                    3.66
# Aston Villa                3.28
# Brighton                   3.39
# Burnley                    2.17
# Chelsea                    3.70
# Crystal Palace             1.62
# Everton                    2.47
# Fulham                     2.99
# Leeds United               2.68
# Leicester City             3.35
# Liverpool FC               3.87
# Manchester City            3.88
# Manchester United          3.16
# Newcastle United           2.65
# Sheffield United           3.67
# Southampton                2.37
# Tottenham Hotspur          3.10
# West Bromwich Albion       2.41
# West Ham United            2.75
# Wolverhampton Wanderers    3.10
# Name: xG, dtype: float64

# %%
football2 = pd.read_csv("/Users/linhvien/Downloads/2021-2022 Football Player Stats.csv",sep = ';',encoding = "ISO-8859-1")

# %%
epl = football2[football2.Comp == "Premier League"]

# %%
football3 = pd.read_csv("dataset - 2020-09-24.csv")

# %%
football3.groupby(by=["Club"])["Goals per match"].mean()
# Out:
# Club
# Arsenal                     7.890588
# Aston-Villa                 4.880667
# Brighton-and-Hove-Albion    1.647895
# Burnley                     1.110000
# Chelsea                     0.831429
# Crystal-Palace              2.306667
# Everton                     3.960500
# Fulham                      5.458462
# Leeds-United                3.049333
# Leicester-City              6.495000
# Liverpool                   1.647500
# Manchester-City             3.225625
# Manchester-United           0.253571
# Newcastle-United            0.117059
# Sheffield-United            2.372308
# Southampton                 1.194167
# Tottenham-Hotspur           2.261176
# West-Bromwich-Albion        1.487333
# West-Ham-United             0.591250
# Wolverhampton-Wanderers     0.245833
# Name: Goals per match, dtype: float64

# %%
football4 = pd.read_csv("/Users/linhvien/Downloads/2021_2022_team_stats.csv")

# %%
sns.scatterplot(football4.LgRk,football4.xG)
# Out:
# /Users/linhvien/opt/anaconda3/envs/iod/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LgRk', ylabel='xG'>

# %%
football4[(football4.LgRk>17)&(football4.xG>50)].Squad
# Out:
# 85    Levante
# Name: Squad, dtype: object

# %%
football4[football4.Squad== "Levante"]
# Out:
#     Rk    Squad Country  LgRk  MP  W   D   L  GF  GA  GD  Pts  Pts/G    xG  \
# 85  86  Levante     ESP    19  38  8  11  19  51  76 -25   35   0.92  56.5
#
#      xGA  xGD  xGD/90  Attendance        Top Team Scorer Goalkeeper
# 85  56.2  0.3    0.01       14961  Jos Luis Morales - 13    Crdenas

# %% [markdown]
# ### Levante had defence problems

# %%
football4[(football4.xG>70)]
# Out:
#     Rk            Squad Country  LgRk  MP   W   D   L  GF  GA  GD  Pts  Pts/G  \
# 0    1  Manchester City     ENG     1  38  29   6   3  99  26  73   93   2.45
# 1    2        Liverpool     ENG     2  38  28   8   2  94  26  68   92   2.42
# 2    3    Bayern Munich     GER     1  34  24   5   5  97  37  60   77   2.26
# 3    4        Paris S-G     FRA     1  38  26   8   4  90  36  54   86   2.26
# 4    5      Real Madrid     ESP     1  38  26   8   4  80  31  49   86   2.26
# 6    7            Inter     ITA     2  38  25   9   4  84  32  52   84   2.21
# 31  32             Lyon     FRA     8  38  17  11  10  66  51  15   61   1.61
#
#       xG   xGA   xGD  xGD/90  Attendance          Top Team Scorer  \
# 0   89.0  27.2  61.9    1.63       52774     Kevin De Bruyne - 15
# 1   89.2  34.2  55.0    1.45       53367       Mohamed Salah - 23
# 2   88.1  37.1  51.0    1.50       33176  Robert Lewandowski - 35
# 3   76.5  38.6  37.9    1.00       41188        Kylian Mbapp - 28
# ...

# %%
football4['diff_G_xG'] = football4.GF - football4.xG

# %%
football4['diff_GA_xGA'] = football4.GA - football4.xGA

# %%
football4[football4.xG>70]
# Out:
#     Rk            Squad Country  LgRk  MP   W   D   L  GF  GA  ...  Pts/G  \
# 0    1  Manchester City     ENG     1  38  29   6   3  99  26  ...   2.45
# 1    2        Liverpool     ENG     2  38  28   8   2  94  26  ...   2.42
# 2    3    Bayern Munich     GER     1  34  24   5   5  97  37  ...   2.26
# 3    4        Paris S-G     FRA     1  38  26   8   4  90  36  ...   2.26
# 4    5      Real Madrid     ESP     1  38  26   8   4  80  31  ...   2.26
# 6    7            Inter     ITA     2  38  25   9   4  84  32  ...   2.21
# 31  32             Lyon     FRA     8  38  17  11  10  66  51  ...   1.61
#
#       xG   xGA   xGD  xGD/90  Attendance          Top Team Scorer  \
# 0   89.0  27.2  61.9    1.63       52774     Kevin De Bruyne - 15
# 1   89.2  34.2  55.0    1.45       53367       Mohamed Salah - 23
# 2   88.1  37.1  51.0    1.50       33176  Robert Lewandowski - 35
# 3   76.5  38.6  37.9    1.00       41188        Kylian Mbapp - 28
# ...

# %% [markdown]
# ### Lyon has a problem when it came to convert their chances. They also had problem in defence.

# %%
football4.dtypes
# Out:
# Rk                   int64
# Squad               object
# Country             object
# LgRk                 int64
# MP                   int64
# W                    int64
# D                    int64
# L                    int64
# GF                   int64
# GA                   int64
# GD                   int64
# Pts                  int64
# Pts/G              float64
# xG                 float64
# xGA                float64
# xGD                float64
# xGD/90             float64
# Attendance           int64
# Top Team Scorer     object
# Goalkeeper          object
# diff_G_xG          float64
# diff_GA_xGA        float64
# dtype: object

# %%
football4.corr()
# Out:
#                    Rk      LgRk            MP         W         D         L  \
# Rk           1.000000  0.987622  3.726198e-02 -0.959480  0.285812  0.924456
# LgRk         0.987622  1.000000  6.819932e-02 -0.944172  0.295908  0.910882
# MP           0.037262  0.068199  1.000000e+00  0.070581  0.247883  0.078869
# W           -0.959480 -0.944172  7.058124e-02  1.000000 -0.416057 -0.865561
# D            0.285812  0.295908  2.478828e-01 -0.416057  1.000000 -0.017118
# L            0.924456  0.910882  7.886918e-02 -0.865561 -0.017118  1.000000
# GF          -0.860073 -0.838473 -1.815342e-02  0.886125 -0.345521 -0.803689
# GA           0.830224  0.825765 -2.174962e-02 -0.790530  0.062542  0.842207
# GD          -0.948227 -0.932766  4.924077e-15  0.943905 -0.242836 -0.919908
# Pts         -0.967007 -0.949160  1.178924e-01  0.987131 -0.265494 -0.920807
# Pts/G       -0.979320 -0.964640 -1.077339e-02  0.984751 -0.303532 -0.935031
# ...

# %%
sns.scatterplot(football4.LgRk, football4.GD)
# Out:
# /Users/linhvien/opt/anaconda3/envs/iod/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LgRk', ylabel='GD'>

# %%
football4[football4.GD>40]
# Out:
#     Rk            Squad Country  LgRk  MP   W   D   L  GF  GA  ...  Pts/G  \
# 0    1  Manchester City     ENG     1  38  29   6   3  99  26  ...   2.45
# 1    2        Liverpool     ENG     2  38  28   8   2  94  26  ...   2.42
# 2    3    Bayern Munich     GER     1  34  24   5   5  97  37  ...   2.26
# 3    4        Paris S-G     FRA     1  38  26   8   4  90  36  ...   2.26
# 4    5      Real Madrid     ESP     1  38  26   8   4  80  31  ...   2.26
# 6    7            Inter     ITA     2  38  25   9   4  84  32  ...   2.21
# 7    8           Napoli     ITA     3  38  24   7   7  74  31  ...   2.08
# 9   10          Chelsea     ENG     3  38  21  11   6  76  33  ...   1.95
# 19  20           Rennes     FRA     4  38  20   6  12  82  40  ...   1.74
#
#       xG   xGA   xGD  xGD/90  Attendance          Top Team Scorer  \
# 0   89.0  27.2  61.9    1.63       52774     Kevin De Bruyne - 15
# 1   89.2  34.2  55.0    1.45       53367       Mohamed Salah - 23
# ...

# %%
football4[(football4.LgRk <5) & (football4.Country =="ENG")].transpose()
# Out:
#                                    0                   1                 9   \
# Rk                                  1                   2                10
# Squad                 Manchester City           Liverpool           Chelsea
# Country                           ENG                 ENG               ENG
# LgRk                                1                   2                 3
# MP                                 38                  38                38
# W                                  29                  28                21
# D                                   6                   8                11
# L                                   3                   2                 6
# GF                                 99                  94                76
# GA                                 26                  26                33
# GD                                 73                  68                43
# ...

# %% [markdown]
# ### Chelsea & Totenham conversion rate is higher than xG. Their problems is not at the main striker, but at the creative players, or tactic that prevending them to create chances.

# %%
epl.columns.values.tolist()
# Out:
# ['Rk',
#  'Player',
#  'Nation',
#  'Pos',
#  'Squad',
#  'Comp',
#  'Age',
#  'Born',
#  'MP',
#  'Starts',
#  'Min',
#  '90s',
#  'Goals',
#  'Shots',
#  'SoT',
#  'SoT%',
#  'G/Sh',
#  'G/SoT',
#  'ShoDist',
#  'ShoFK',
#  'ShoPK',
#  'PKatt',
#  'PasTotCmp',
#  'PasTotAtt',
#  'PasTotCmp%',
#  'PasTotDist',
#  'PasTotPrgDist',
#  'PasShoCmp',
#  'PasShoAtt',
#  'PasShoCmp%',
#  'PasMedCmp',
#  'PasMedAtt',
#  'PasMedCmp%',
#  'PasLonCmp',
#  'PasLonAtt',
#  'PasLonCmp%',
#  'Assists',
#  'PasAss',
#  'Pas3rd',
#  'PPA',
#  'CrsPA',
#  'PasProg',
#  'PasAtt',
#  'PasLive',
#  'PasDead',
#  'PasFK',
#  'TB',
#  'PasPress',
#  'Sw',
#  'PasCrs',
#  'CK',
#  'CkIn',
#  'CkOut',
#  'CkStr',
#  'PasGround',
#  'PasLow',
#  'PasHigh',
#  'PaswLeft',
#  'PaswRight',
#  'PaswHead',
#  'TI',
#  'PaswOther',
#  'PasCmp',
#  'PasOff',
#  'PasOut',
#  'PasInt',
#  'PasBlocks',
#  'SCA',
#  'ScaPassLive',
#  'ScaPassDead',
#  'ScaDrib',
#  'ScaSh',
#  'ScaFld',
#  'ScaDef',
#  'GCA',
# ...

# %%
top4epl = epl[(epl.Squad =="Chelsea") | (epl.Squad =="Liverpool") | (epl.Squad == "Manchester City") | (epl.Squad =="Tottenham")]

# %%
top4epl["Shot_per_season"]=top4epl["Shots"]*top4epl["90s"]
# Out:
# /var/folders/mf/7c7p544j17b4t3yzzvvx6hs80000gq/T/ipykernel_68033/3838580597.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top4epl["Shot_per_season"]=top4epl["Shots"]*top4epl["90s"]

# %%
top4epl.groupby(by="Squad")["Shot_per_season"].sum()
# Out:
# Squad
# Chelsea            585.047
# Liverpool          721.719
# Manchester City    703.749
# Tottenham          490.906
# Name: Shot_per_season, dtype: float64

# %% [markdown]
# ### Top2 took alot of shots

# %%
top4epl.groupby(by="Squad")["ShoDist"].median()
# Out:
# Squad
# Chelsea            17.75
# Liverpool          16.00
# Manchester City    13.50
# Tottenham          15.60
# Name: ShoDist, dtype: float64

# %% [markdown]
# ## Man city tends to perform short range shots

# %%
top4epl.groupby(by="Squad")["PasTotCmp"].mean()
# Out:
# Squad
# Chelsea            47.861538
# Liverpool          49.307407
# Manchester City    50.076923
# Tottenham          38.852000
# Name: PasTotCmp, dtype: float64

# %% [markdown]
# ### Top 3 has high pass completion

# %%
top4epl["Pas3rd_season"] = top4epl.Pas3rd*top4epl["90s"]
# Out:
# /var/folders/mf/7c7p544j17b4t3yzzvvx6hs80000gq/T/ipykernel_68033/1377949276.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top4epl["Pas3rd_season"] = top4epl.Pas3rd*top4epl["90s"]

# %%
top4epl.groupby(by="Squad")["Pas3rd_season"].sum()
# Out:
# Squad
# Chelsea            1560.877
# Liverpool          1823.697
# Manchester City    1946.191
# Tottenham          1183.871
# Name: Pas3rd_season, dtype: float64

# %% [markdown]
# ### Top 2 passing playing more in the last 1/3

# %%
top4epl.groupby(by="Squad")["PaswHead_season"].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 top4epl.groupby(by="Squad")["PaswHead_season"].sum()
#
# File ~/opt/anaconda3/envs/iod/lib/python3.9/site-packages/pandas/core/groupby/generic.py:1338, in DataFrameGroupBy.__getitem__(self, key)
#    1329 if isinstance(key, tuple) and len(key) > 1:
#    1330     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1331     # valid syntax, so don't raise warning
#    1332     warnings.warn(
#    1333         "Indexing with multiple keys (implicitly converted to a tuple "
#    1334         "of keys) will be deprecated, use a list instead.",
#    1335         FutureWarning,
#    1336         stacklevel=find_stack_level(),
#    1337     )
# -> 1338 return super().__getitem__(key)
#
# ...

# %% [markdown]
# ### Liverpool had a lot more headers than other team

# %%
top4epl["GCA_season"]=top4epl["GCA"]*top4epl["90s"]

# %%
top4epl[top4epl.Squad=="Liverpool"]["GCA_season"]

# %%
top4epl.groupby(by="Squad").GCA_season.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 top4epl.groupby(by="Squad").GCA_season.sum()
#
# File ~/opt/anaconda3/envs/iod/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'GCA_season'

# %%
top4epl.loc[:,["GCA","Min","Squad"]]

# %%
top4epl["GCA_Min"] = top4epl.GCA*top4epl.Min

# %%
top4epl.groupby(by = "Squad").GCA_Min.sum()

# %%
top4epl[top4epl.GCA_Min>0].groupby(by="Squad").GCA_Min.count()

# %%
top4epl["GCA_season"]=top4epl.GCA*top4epl["90s"]

# %%
top4epl.sort_values(by = ["GCA_season"],ascending = False).head(10)

# %%
top_creative_min = top4epl[(top4epl.SCA>0)&(top4epl.Min>270)].loc[:,["Player","Squad",'Min','SCA']].sort_values(by="SCA",ascending = False).head(10)

# %%
top_creative_min.groupby(by = "Squad")["Min"].sum()

# %% [markdown]
# ### Top 10 creative players, who play regularly in the team, Manchester City and Liverpool are those teams which got the most out of these creative players

# %%
top_creative_min = top4epl[(top4epl.SCA>0)&(top4epl.Min>270)].loc[:,["Player","Squad",'Min','SCA']].sort_values(by="SCA",ascending = False).head(10)

# %%
import matplotlib.pyplot as plt

a = top_creative_min.groupby(by = "Squad").Min.sum().values
palette_color = sns.color_palette('dark')
  
# plotting data on chart
plt.pie(a, labels="Top Creative Players Contributions in Minutes", colors=palette_color)
  
# displaying chart
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [108], in <cell line: 7>()
#       4 palette_color = sns.color_palette('dark')
#       6 # plotting data on chart
# ----> 7 plt.pie(a, labels="Top Creative Players Contributions in Minutes", colors=palette_color)
#       9 # displaying chart
#      10 plt.show()
#
# File ~/opt/anaconda3/envs/iod/lib/python3.9/site-packages/matplotlib/pyplot.py:2744, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2737 @_copy_docstring_and_deprecators(Axes.pie)
#    2738 def pie(
#    2739         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2742         textprops=None, center=(0, 0), frame=False,
#    2743         rotatelabels=False, *, normalize=True, data=None):
# ...

# %% [markdown]
# # Defences

# %%
top4epl.sort_values(by="ScaDef",ascending = False).loc[:,["Player","ScaDef","Pos","Squad"]].head(20)

# %% [markdown]
# ### Chelsea and Liverpool FW & MF are good at pressuring high up the pitch, and win back the ball as soon as they lose possition

# %%
top4epl.GcaPassDead.sort_values(ascending= False)

# %%
top4epl["GcaPassDead_season"] = top4epl.GcaPassDead*top4epl["90s"]

# %%
top4epl.groupby(by=['Squad'])["GcaPassDead_season"].sum()

# %%
top4epl["TklWon_season"] = top4epl.TklWon*top4epl["90s"]

# %%
top4epl.groupby(by=['Squad'])["TklWon_season"].sum()

# %%
top4epl["TklDef3rd_season"] = top4epl.TklDef3rd*top4epl["90s"]

# %%
top4epl.groupby(by=['Squad'])["TklDef3rd_season"].sum()

# %%
top4epl["PasTotCmp_season"] = top4epl.PasTotCmp*top4epl["90s"]

# %%
top4epl.groupby(by=['Squad'])["PasTotCmp_season"].sum()

# %%
season_player_stats = pd.read_csv("/Users/linhvien/Downloads/2021-2022 Football Player Stats.csv",sep = ';',encoding = "ISO-8859-1")
football5 = pd.read_csv("/Users/linhvien/Downloads/2021-2022 Football Player Stats.csv",sep = ';',encoding = "ISO-8859-1")

# %%
season_playermetric  = [ 'Goals',
 'Shots',
 'SoT',
 'SoT%',
 'G/Sh',
 'G/SoT',
 'ShoDist',
 'ShoFK',
 'ShoPK',
 'PKatt',
 'PasTotCmp',
 'PasTotAtt',
 'PasTotCmp%',
 'PasTotDist',
 'PasTotPrgDist',
 'PasShoCmp',
 'PasShoAtt',
 'PasShoCmp%',
 'PasMedCmp',
 'PasMedAtt',
 'PasMedCmp%',
 'PasLonCmp',
 'PasLonAtt',
 'PasLonCmp%',
 'Assists',
 'PasAss',
 'Pas3rd',
 'PPA',
 'CrsPA',
 'PasProg',
 'PasAtt',
 'PasLive',
 'PasDead',
 'PasFK',
 'TB',
 'PasPress',
 'Sw',
 'PasCrs',
 'CK',
 'CkIn',
 'CkOut',
 'CkStr',
 'PasGround',
 'PasLow',
 'PasHigh',
 'PaswLeft',
 'PaswRight',
 'PaswHead',
 'TI',
 'PaswOther',
 'PasCmp',
 'PasOff',
 'PasOut',
 'PasInt',
 'PasBlocks',
 'SCA',
 'ScaPassLive',
 'ScaPassDead',
 'ScaDrib',
 'ScaSh',
 'ScaFld',
 'ScaDef',
 'GCA',
 'GcaPassLive',
 'GcaPassDead',
 'GcaDrib',
 'GcaSh',
 'GcaFld',
 'GcaDef',
 'Tkl',
 'TklWon',
 'TklDef3rd',
 'TklMid3rd',
 'TklAtt3rd',
 'TklDri',
 'TklDriAtt',
 'TklDri%',
 'TklDriPast',
 'Press',
 'PresSucc',
 'Press%',
 'PresDef3rd',
 'PresMid3rd',
 'PresAtt3rd',
 'Blocks',
 'BlkSh',
 'BlkShSv',
 'BlkPass',
 'Int',
 'Tkl+Int',
 'Clr',
 'Err',
 'Touches',
 'TouDefPen',
 'TouDef3rd',
 'TouMid3rd',
 'TouAtt3rd',
 'TouAttPen',
 'TouLive',
 'DriSucc',
 'DriAtt',
 'DriSucc%',
 'DriPast',
 'DriMegs',
 'Carries',
 'CarTotDist',
 'CarPrgDist',
 'CarProg',
 'Car3rd',
 'CPA',
 'CarMis',
 'CarDis',
 'RecTarg',
 'Rec',
 'Rec%',
 'RecProg',
 'CrdY',
 'CrdR',
 '2CrdY',
 'Fls',
 'Fld',
 'Off',
 'Crs',
 'TklW',
 'PKwon',
 'PKcon',
 'OG',
 'Recov',
 'AerWon',
 'AerLost',
 'AerWon%']

# %%
for i in season_playermetric:
    season_player_stats[i] = season_player_stats[i]*season_player_stats["90s"]

# %%
season_player_stats.head()
# Out:
#    Rk             Player Nation Pos          Squad            Comp   Age  \
# 0   1         Max Aarons    ENG  DF   Norwich City  Premier League  22.0
# 1   2   Yunis Abdelhamid    MAR  DF          Reims         Ligue 1  34.0
# 2   3  Salis Abdul Samed    GHA  MF  Clermont Foot         Ligue 1  22.0
# 3   4    Laurent Abergel    FRA  MF        Lorient         Ligue 1  29.0
# 4   5        Charles Abi    FRA  FW  Saint-Étienne         Ligue 1  22.0
#
#    Born  MP  Starts  ...    Off     Crs    TklW  PKwon  PKcon    OG    Recov  \
# 0  2000  34      32  ...  0.960  45.120  37.120    0.0  1.920  0.96  176.960
# 1  1987  34      34  ...  0.000   1.986  46.009    0.0  0.993  0.00  224.087
# 2  2000  31      29  ...  0.000   9.864  33.976    0.0  0.000  0.00  240.024
# 3  1993  34      34  ...  0.984  25.912  73.144    0.0  0.000  0.00  290.936
# 4  2000   1       1  ...  0.000   1.000   0.000    0.0  0.000  0.00    2.000
#
#    AerWon  AerLost  AerWon%
# 0  15.040   50.880   726.40
# ...

# %%
football5.head()
# Out:
#    Rk             Player Nation Pos          Squad            Comp   Age  \
# 0   1         Max Aarons    ENG  DF   Norwich City  Premier League  22.0
# 1   2   Yunis Abdelhamid    MAR  DF          Reims         Ligue 1  34.0
# 2   3  Salis Abdul Samed    GHA  MF  Clermont Foot         Ligue 1  22.0
# 3   4    Laurent Abergel    FRA  MF        Lorient         Ligue 1  29.0
# 4   5        Charles Abi    FRA  FW  Saint-Étienne         Ligue 1  22.0
#
#    Born  MP  Starts  ...   Off   Crs  TklW  PKwon  PKcon    OG  Recov  AerWon  \
# 0  2000  34      32  ...  0.03  1.41  1.16    0.0   0.06  0.03   5.53    0.47
# 1  1987  34      34  ...  0.00  0.06  1.39    0.0   0.03  0.00   6.77    2.02
# 2  2000  31      29  ...  0.00  0.36  1.24    0.0   0.00  0.00   8.76    0.88
# 3  1993  34      34  ...  0.03  0.79  2.23    0.0   0.00  0.00   8.87    0.43
# 4  2000   1       1  ...  0.00  2.00  0.00    0.0   0.00  0.00   4.00    2.00
#
#    AerLost  AerWon%
# 0     1.59     22.7
# ...

# %%
epl_players_season = season_player_stats[season_player_stats["Comp"] == "Premier League"]

# %%
epl_players = football5[football5.Comp =="Premier League"]
sns.boxplot()
# Out:
# <AxesSubplot:>

# %%
def display_players_season_stats(stat,stat_describe):
    sns.set(rc={'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'})
    a = epl_players_season.groupby(by = "Squad")[stat].sum()
    fig = sns.boxplot(x = a)
    fig.set_title(stat_describe)
    
    fig.get_figure().savefig(stat_describe+".jpg") 
    print(epl_players_season.groupby(by = "Squad")[stat].sum().sort_values(ascending=False).head(10))

# %%
display_players_season_stats("Crs","Cross Per Season")
# Out:
# Squad
# Manchester City    609.978
# Liverpool          554.343
# West Ham           521.463
# Chelsea            496.433
# Brighton           486.014
# Aston Villa        452.052
# Burnley            450.259
# Southampton        449.917
# Leeds United       436.063
# Arsenal            433.081
# Name: Crs, dtype: float64

# %% [markdown]
# ### Manchester City and Liverpool cross more than other teams. They are the outliers in the boxplot

# %%
display_players_season_stats("Shots", "Shots per season")
# Out:
# Squad
# Liverpool          721.719
# Manchester City    703.749
# Chelsea            585.047
# Arsenal            580.521
# Manchester Utd     504.731
# Tottenham          490.906
# Leeds United       484.892
# Southampton        483.169
# Brighton           482.877
# Aston Villa        461.006
# Name: Shots, dtype: float64

# %%
display_players_season_stats("PasTotCmp", "Pass Completed Per Season")
# Out:
# Squad
# Manchester City    24031.320
# Chelsea            20885.030
# Liverpool          20857.780
# Tottenham          16912.680
# Manchester Utd     16463.850
# Brighton           16340.355
# Arsenal            16113.630
# Leicester City     15912.225
# Wolves             15022.780
# Crystal Palace     14780.470
# Name: PasTotCmp, dtype: float64

# %%
display_players_season_stats("PasCmp", )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [79], in <cell line: 1>()
# ----> 1 display_players_season_stats("PasCmp")
#
# TypeError: display_players_season_stats() missing 1 required positional argument: 'stat_describe'

# %% [markdown]
# ### MAN CITY PASS A LOT MORE

# %%
display_players_season_stats("PaswLeft","Pass With Left Foot")
# Out:
# Squad
# Manchester City    10089.630
# Arsenal             8200.230
# Leeds United        7342.445
# Liverpool           5943.921
# Manchester Utd      5806.096
# Wolves              5572.118
# Chelsea             5290.942
# Aston Villa         5278.819
# Tottenham           5056.291
# Brighton            4979.475
# Name: PaswLeft, dtype: float64

# %%
display_players_season_stats("PaswRight","Pass With Right Foot")
# Out:
# Squad
# Chelsea            16995.801
# Liverpool          16646.994
# Manchester City    15244.474
# Tottenham          13171.910
# Brighton           13095.189
# Leicester City     12674.331
# Manchester Utd     12263.950
# Crystal Palace     11550.407
# West Ham           11240.655
# Wolves             10916.565
# Name: PaswRight, dtype: float64

# %%
display_players_season_stats("PaswHead")

# %%
display_players_season_stats("SCA", "Shot Creating Actions")
# Out:
# Squad
# Manchester City    1146.082
# Liverpool          1092.164
# Chelsea             963.923
# Arsenal             920.876
# Manchester Utd      841.155
# Tottenham           817.157
# Brighton            748.226
# Southampton         732.445
# Aston Villa         724.762
# Leeds United        711.321
# Name: SCA, dtype: float64

# %%
display_players_season_stats("ScaPassLive")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [87], in <cell line: 1>()
# ----> 1 display_players_season_stats("ScaPassLive")
#
# TypeError: display_players_season_stats() missing 1 required positional argument: 'stat_describe'

# %%
display_players_season_stats("ScaPassDead")

# %%
display_players_season_stats("GcaPassLive")

# %%
display_players_season_stats("TB","Through Balls")
# Out:
# Squad
# Liverpool          73.150
# Manchester City    63.794
# Chelsea            60.772
# Tottenham          57.638
# Manchester Utd     47.788
# Aston Villa        35.062
# West Ham           33.818
# Leicester City     30.985
# Wolves             29.652
# Arsenal            28.150
# Name: TB, dtype: float64

# %%
display_players_season_stats("Sw")

# %%
display_players_season_stats("PasCrs")

# %%
display_players_season_stats("CK")

# %%
display_players_season_stats("PasGround")

# %%
display_players_season_stats("PaswLeft")

# %%
display_players_season_stats("PaswRight")

# %%
display_players_season_stats("PasBlocks")

# %%
display_players_season_stats("PasInt")

# %%
display_players_season_stats("SCA")

# %%
display_players_season_stats("CrsPA")

# %%
display_players_season_stats("PasProg","Completed passes that move the ball towards the opponent's goal")
# Out:
# Squad
# Liverpool          1966.867
# Manchester City    1766.320
# Chelsea            1614.232
# Tottenham          1318.238
# Manchester Utd     1303.586
# Leeds United       1277.954
# Brighton           1210.387
# Arsenal            1168.357
# Leicester City     1143.709
# West Ham           1122.954
# Name: PasProg, dtype: float64

# %%
display_players_season_stats("ScaDrib")

# %% [markdown]
# ## Top clubs see goal responsibility sharing among teammates. In other words, Top clubs have more goal scorers in their teams.

# %% [markdown]
# ### Liverpool & city cross alot

# %% [markdown]
# ## Man city has more balance between left and right. Liverpool, chelsea & tottenham play more on the right.

# %%
display_players_season_stats("ScaDef")

# %% [markdown]
# # Chelsea and liverpool need a good left foot attacker. Top 10 creative players, who play regularly in the team, Manchester City and Liverpool are those teams which got the most out of these creative players, and Chelsea need to improve. & That is the reason Liverpool & Manchester City are scoring a lot of goals. They are able to create more chances by getting the most out of their creative players.

# %%
epl_players[(epl_players["90s"]>19) & (epl_players.Squad =="Liverpool")].loc[:,["Squad","PasTotCmp%","Player","SCA"]].sort_values(by="PasTotCmp%")
# Out:
#           Squad  PasTotCmp%                  Player   SCA
# 1302  Liverpool        73.7              Diogo Jota  3.31
# 62    Liverpool        74.4  Trent Alexander-Arnold  4.73
# 1640  Liverpool        75.1              Sadio Mané  3.10
# 2360  Liverpool        77.7           Mohamed Salah  4.33
# 2275  Liverpool        81.0        Andrew Robertson  3.37
# 1154  Liverpool        83.8        Jordan Henderson  2.70
# 65    Liverpool        86.6                 Alisson  0.08
# 843   Liverpool        88.1                 Fabinho  1.52
# 1706  Liverpool        90.0              Joël Matip  1.10
# 718   Liverpool        90.8         Virgil van Dijk  0.71

# %%
epl_players[(epl_players["90s"]>19) & (epl_players.Squad =="Chelsea")].loc[:,["PasTotCmp%","Player","SCA"]].sort_values(by="PasTotCmp%")
# Out:
#       PasTotCmp%             Player   SCA
# 71          77.7      Marcos Alonso  3.69
# 1859        77.9        Mason Mount  4.22
# 1144        81.6        Kai Havertz  2.64
# 1761        83.2      Edouard Mendy  0.06
# 155         84.2  César Azpilicueta  1.91
# 1264        86.5        Reece James  3.82
# 1344        87.1       N'Golo Kanté  3.10
# 2325        88.4    Antonio Rüdiger  1.16
# 1296        89.7           Jorginho  2.37
# 2489        92.9       Thiago Silva  0.88

# %%
epl_players[(epl_players["90s"]>19) & (epl_players.Squad =="Manchester City")].loc[:,["PasTotCmp%","Player","SCA"]].sort_values(by="PasTotCmp%")
# Out:
#       PasTotCmp%           Player   SCA
# 646         75.5  Kevin De Bruyne  5.67
# 899         80.7       Phil Foden  3.52
# 2565        82.4  Raheem Sterling  3.81
# 450         83.9     João Cancelo  2.87
# 1280        84.2    Gabriel Jesus  3.73
# 1058        86.5    Jack Grealish  5.16
# 1103        87.5   Ýlkay Gündoðan  3.45
# 2482        88.4   Bernardo Silva  4.01
# 2816        88.9      Kyle Walker  1.85
# 799         89.6          Ederson  0.11
# 2283        92.5            Rodri  2.34
# 705         94.3       Rúben Dias  1.12
# 1472        94.7  Aymeric Laporte  0.96

# %%
football5.head(10)

# %%
football5[football5.Player == "Aaron Ramsdale"]["Shots"]

# %% [markdown]
# ### Attacking Defence Goalkeeper:
# Attack: GoALS, CHANCE CREATED, NUMBER SHOT ....
# DEFENCE : TACKLE:
# GK : SAVES. 100 Shots on target . 99 shots.

# %%
attacking_metric = ["Player","Pos","Shots","Crs","SoT%","G/Sh","ShoDist","PasTotCmp%","Assists","PasAss","Pas3rd","PPA"
                   ,"TB","PasPress","PasCmp"]

# %%
football5[(football5.Squad == "Manchester City")&((football5.Pos =="FW")| (football5.Pos =="MF")) ].loc[:,attacking_metric]

# %%
football5.Pos.unique()

# %% [markdown]
# ### H0 THere is no different between number of shots between midfielder and FW

# %%
shot_midfield = football5[football5.Pos =="MF"]["Shots"].sample(100,random_state = 1)
shot_FW = football5[football5.Pos =="FW"]["Shots"].sample(100,random_state = 1)

# %%
def print_sig(p_value, alpha):
    if p_value < alpha:
        print("We reject our null hypothesis.")
    elif p_value > alpha:
        print("We fail to reject our null hypothesis.")
    else:
        print("Our test is inconclusive.")

# %%
from scipy import stats

t2, p2 = stats.ttest_ind(shot_midfield,shot_FW)
print("t = " + str(t2))
print("p = " + str(p2))

print_sig(p2, 0.05)

# %%
football5["Shots"].sample(100,random_state = 1)
sns.histplot(x = shot_midfield)
