# %%
import pandas as pd
import seaborn as sns

# %%
football = pd.read_csv('/Users/linhvien/Downloads/EPL_20_21.csv')

# %%
football.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards
# ...

# %%
football[football.Goals>0].groupby(by = ["Club"]).agg({"Name":"count"}).sort_values(by="Name")
# Out:
#                          Name
# Club
# Sheffield United            9
# Everton                    10
# West Bromwich Albion       11
# Aston Villa                12
# Burnley                    12
# Tottenham Hotspur          12
# Fulham                     12
# Southampton                12
# Leeds United               13
# Crystal Palace             14
# Arsenal                    15
# Newcastle United           15
# Leicester City             15
# West Ham United            15
# Brighton                   15
# Wolverhampton Wanderers    15
# Manchester City            16
# Liverpool FC               16
# Chelsea                    16
# Manchester United          16

# %%
football.groupby(by = ["Club"])["xG"].sum()
# Out:
# Club
# Arsenal                    3.66
# Aston Villa                3.28
# Brighton                   3.39
# Burnley                    2.17
# Chelsea                    3.70
# Crystal Palace             1.62
# Everton                    2.47
# Fulham                     2.99
# Leeds United               2.68
# Leicester City             3.35
# Liverpool FC               3.87
# Manchester City            3.88
# Manchester United          3.16
# Newcastle United           2.65
# Sheffield United           3.67
# Southampton                2.37
# Tottenham Hotspur          3.10
# West Bromwich Albion       2.41
# West Ham United            2.75
# Wolverhampton Wanderers    3.10
# Name: xG, dtype: float64

# %% [markdown]
# ## Top clubs see goal responsibility sharing among teammates. In other words, Top clubs have more goal scorers in their teams.

# %%
football2 = pd.read_csv("/Users/linhvien/Downloads/2021-2022 Football Player Stats.csv",sep = ';',encoding = "ISO-8859-1")

# %%
epl = football2[football2.Comp == "Premier League"]

# %%
football3 = pd.read_csv("dataset - 2020-09-24.csv")

# %%
football3.groupby(by=["Club"])["Goals per match"].mean()
# Out:
# Club
# Arsenal                     7.890588
# Aston-Villa                 4.880667
# Brighton-and-Hove-Albion    1.647895
# Burnley                     1.110000
# Chelsea                     0.831429
# Crystal-Palace              2.306667
# Everton                     3.960500
# Fulham                      5.458462
# Leeds-United                3.049333
# Leicester-City              6.495000
# Liverpool                   1.647500
# Manchester-City             3.225625
# Manchester-United           0.253571
# Newcastle-United            0.117059
# Sheffield-United            2.372308
# Southampton                 1.194167
# Tottenham-Hotspur           2.261176
# West-Bromwich-Albion        1.487333
# West-Ham-United             0.591250
# Wolverhampton-Wanderers     0.245833
# Name: Goals per match, dtype: float64

# %%
football4 = pd.read_csv("/Users/linhvien/Downloads/2021_2022_team_stats.csv")

# %%
sns.scatterplot(football4.LgRk,football4.xG)
# Out:
# /Users/linhvien/opt/anaconda3/envs/iod/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LgRk', ylabel='xG'>

# %%
football4[(football4.LgRk>17)&(football4.xG>50)].Squad
# Out:
# 85    Levante
# Name: Squad, dtype: object

# %%
football4[football4.Squad== "Levante"]
# Out:
#     Rk    Squad Country  LgRk  MP  W   D   L  GF  GA  GD  Pts  Pts/G    xG  \
# 85  86  Levante     ESP    19  38  8  11  19  51  76 -25   35   0.92  56.5
#
#      xGA  xGD  xGD/90  Attendance        Top Team Scorer Goalkeeper
# 85  56.2  0.3    0.01       14961  Jos Luis Morales - 13    Crdenas

# %% [markdown]
# ### Levante had defence problems

# %%
football4[(football4.xG>70)]
# Out:
#     Rk            Squad Country  LgRk  MP   W   D   L  GF  GA  GD  Pts  Pts/G  \
# 0    1  Manchester City     ENG     1  38  29   6   3  99  26  73   93   2.45
# 1    2        Liverpool     ENG     2  38  28   8   2  94  26  68   92   2.42
# 2    3    Bayern Munich     GER     1  34  24   5   5  97  37  60   77   2.26
# 3    4        Paris S-G     FRA     1  38  26   8   4  90  36  54   86   2.26
# 4    5      Real Madrid     ESP     1  38  26   8   4  80  31  49   86   2.26
# 6    7            Inter     ITA     2  38  25   9   4  84  32  52   84   2.21
# 31  32             Lyon     FRA     8  38  17  11  10  66  51  15   61   1.61
#
#       xG   xGA   xGD  xGD/90  Attendance          Top Team Scorer  \
# 0   89.0  27.2  61.9    1.63       52774     Kevin De Bruyne - 15
# 1   89.2  34.2  55.0    1.45       53367       Mohamed Salah - 23
# 2   88.1  37.1  51.0    1.50       33176  Robert Lewandowski - 35
# 3   76.5  38.6  37.9    1.00       41188        Kylian Mbapp - 28
# ...

# %%
football4['diff_G_xG'] = football4.GF - football4.xG

# %%
football4['diff_GA_xGA'] = football4.GA - football4.xGA

# %%
football4[football4.xG>70]
# Out:
#     Rk            Squad Country  LgRk  MP   W   D   L  GF  GA  ...  Pts/G  \
# 0    1  Manchester City     ENG     1  38  29   6   3  99  26  ...   2.45
# 1    2        Liverpool     ENG     2  38  28   8   2  94  26  ...   2.42
# 2    3    Bayern Munich     GER     1  34  24   5   5  97  37  ...   2.26
# 3    4        Paris S-G     FRA     1  38  26   8   4  90  36  ...   2.26
# 4    5      Real Madrid     ESP     1  38  26   8   4  80  31  ...   2.26
# 6    7            Inter     ITA     2  38  25   9   4  84  32  ...   2.21
# 31  32             Lyon     FRA     8  38  17  11  10  66  51  ...   1.61
#
#       xG   xGA   xGD  xGD/90  Attendance          Top Team Scorer  \
# 0   89.0  27.2  61.9    1.63       52774     Kevin De Bruyne - 15
# 1   89.2  34.2  55.0    1.45       53367       Mohamed Salah - 23
# 2   88.1  37.1  51.0    1.50       33176  Robert Lewandowski - 35
# 3   76.5  38.6  37.9    1.00       41188        Kylian Mbapp - 28
# ...

# %% [markdown]
# ### Lyon has a problem when it came to convert their chances. They also had problem in defence.

# %%
football4.dtypes
# Out:
# Rk                   int64
# Squad               object
# Country             object
# LgRk                 int64
# MP                   int64
# W                    int64
# D                    int64
# L                    int64
# GF                   int64
# GA                   int64
# GD                   int64
# Pts                  int64
# Pts/G              float64
# xG                 float64
# xGA                float64
# xGD                float64
# xGD/90             float64
# Attendance           int64
# Top Team Scorer     object
# Goalkeeper          object
# diff_G_xG          float64
# diff_GA_xGA        float64
# dtype: object

# %%
football4.corr()
# Out:
#                    Rk      LgRk            MP         W         D         L  \
# Rk           1.000000  0.987622  3.726198e-02 -0.959480  0.285812  0.924456
# LgRk         0.987622  1.000000  6.819932e-02 -0.944172  0.295908  0.910882
# MP           0.037262  0.068199  1.000000e+00  0.070581  0.247883  0.078869
# W           -0.959480 -0.944172  7.058124e-02  1.000000 -0.416057 -0.865561
# D            0.285812  0.295908  2.478828e-01 -0.416057  1.000000 -0.017118
# L            0.924456  0.910882  7.886918e-02 -0.865561 -0.017118  1.000000
# GF          -0.860073 -0.838473 -1.815342e-02  0.886125 -0.345521 -0.803689
# GA           0.830224  0.825765 -2.174962e-02 -0.790530  0.062542  0.842207
# GD          -0.948227 -0.932766  4.924077e-15  0.943905 -0.242836 -0.919908
# Pts         -0.967007 -0.949160  1.178924e-01  0.987131 -0.265494 -0.920807
# Pts/G       -0.979320 -0.964640 -1.077339e-02  0.984751 -0.303532 -0.935031
# ...

# %%
sns.scatterplot(football4.LgRk, football4.GD)
# Out:
# /Users/linhvien/opt/anaconda3/envs/iod/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LgRk', ylabel='GD'>

# %%
football4[football4.GD>40]
# Out:
#     Rk            Squad Country  LgRk  MP   W   D   L  GF  GA  ...  Pts/G  \
# 0    1  Manchester City     ENG     1  38  29   6   3  99  26  ...   2.45
# 1    2        Liverpool     ENG     2  38  28   8   2  94  26  ...   2.42
# 2    3    Bayern Munich     GER     1  34  24   5   5  97  37  ...   2.26
# 3    4        Paris S-G     FRA     1  38  26   8   4  90  36  ...   2.26
# 4    5      Real Madrid     ESP     1  38  26   8   4  80  31  ...   2.26
# 6    7            Inter     ITA     2  38  25   9   4  84  32  ...   2.21
# 7    8           Napoli     ITA     3  38  24   7   7  74  31  ...   2.08
# 9   10          Chelsea     ENG     3  38  21  11   6  76  33  ...   1.95
# 19  20           Rennes     FRA     4  38  20   6  12  82  40  ...   1.74
#
#       xG   xGA   xGD  xGD/90  Attendance          Top Team Scorer  \
# 0   89.0  27.2  61.9    1.63       52774     Kevin De Bruyne - 15
# 1   89.2  34.2  55.0    1.45       53367       Mohamed Salah - 23
# ...

# %%
football4[(football4.LgRk <5) & (football4.Country =="ENG")].transpose()
# Out:
#                                    0                   1                 9   \
# Rk                                  1                   2                10
# Squad                 Manchester City           Liverpool           Chelsea
# Country                           ENG                 ENG               ENG
# LgRk                                1                   2                 3
# MP                                 38                  38                38
# W                                  29                  28                21
# D                                   6                   8                11
# L                                   3                   2                 6
# GF                                 99                  94                76
# GA                                 26                  26                33
# GD                                 73                  68                43
# ...

# %% [markdown]
# ### Chelsea & Totenham conversion rate is higher than xG. Their problems is not at the main striker, but at the creative players, or tactic that prevending them to create chances.

# %%
epl.columns.values.tolist()
# Out:
# ['Rk',
#  'Player',
#  'Nation',
#  'Pos',
#  'Squad',
#  'Comp',
#  'Age',
#  'Born',
#  'MP',
#  'Starts',
#  'Min',
#  '90s',
#  'Goals',
#  'Shots',
#  'SoT',
#  'SoT%',
#  'G/Sh',
#  'G/SoT',
#  'ShoDist',
#  'ShoFK',
#  'ShoPK',
#  'PKatt',
#  'PasTotCmp',
#  'PasTotAtt',
#  'PasTotCmp%',
#  'PasTotDist',
#  'PasTotPrgDist',
#  'PasShoCmp',
#  'PasShoAtt',
#  'PasShoCmp%',
#  'PasMedCmp',
#  'PasMedAtt',
#  'PasMedCmp%',
#  'PasLonCmp',
#  'PasLonAtt',
#  'PasLonCmp%',
#  'Assists',
#  'PasAss',
#  'Pas3rd',
#  'PPA',
#  'CrsPA',
#  'PasProg',
#  'PasAtt',
#  'PasLive',
#  'PasDead',
#  'PasFK',
#  'TB',
#  'PasPress',
#  'Sw',
#  'PasCrs',
#  'CK',
#  'CkIn',
#  'CkOut',
#  'CkStr',
#  'PasGround',
#  'PasLow',
#  'PasHigh',
#  'PaswLeft',
#  'PaswRight',
#  'PaswHead',
#  'TI',
#  'PaswOther',
#  'PasCmp',
#  'PasOff',
#  'PasOut',
#  'PasInt',
#  'PasBlocks',
#  'SCA',
#  'ScaPassLive',
#  'ScaPassDead',
#  'ScaDrib',
#  'ScaSh',
#  'ScaFld',
#  'ScaDef',
#  'GCA',
# ...

# %%
top4epl = epl[(epl.Squad =="Chelsea") | (epl.Squad =="Liverpool") | (epl.Squad == "Manchester City") | (epl.Squad =="Tottenham")]

# %%
top4epl["Shot_per_season"]=top4epl["Shots"]*top4epl["90s"]
# Out:
# /var/folders/mf/7c7p544j17b4t3yzzvvx6hs80000gq/T/ipykernel_50964/3838580597.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top4epl["Shot_per_season"]=top4epl["Shots"]*top4epl["90s"]

# %%
top4epl.groupby(by="Squad")["Shot_per_season"].sum()
# Out:
# Squad
# Chelsea            585.047
# Liverpool          721.719
# Manchester City    703.749
# Tottenham          490.906
# Name: Shot_per_season, dtype: float64

# %% [markdown]
# ### Top2 took alot of shots

# %%
top4epl.groupby(by="Squad")["ShoDist"].median()
# Out:
# Squad
# Chelsea            17.75
# Liverpool          16.00
# Manchester City    13.50
# Tottenham          15.60
# Name: ShoDist, dtype: float64

# %% [markdown]
# ## Man city tends to perform short range shots

# %%
top4epl.groupby(by="Squad")["PasTotCmp"].mean()
# Out:
# Squad
# Chelsea            47.861538
# Liverpool          49.307407
# Manchester City    50.076923
# Tottenham          38.852000
# Name: PasTotCmp, dtype: float64

# %% [markdown]
# ### Top 3 has high pass completion

# %%
top4epl["Pas3rd_season"] = top4epl.Pas3rd*top4epl["90s"]
# Out:
# /var/folders/mf/7c7p544j17b4t3yzzvvx6hs80000gq/T/ipykernel_50964/1377949276.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top4epl["Pas3rd_season"] = top4epl.Pas3rd*top4epl["90s"]

# %%
top4epl.groupby(by="Squad")["Pas3rd_season"].sum()
# Out:
# Squad
# Chelsea            1560.877
# Liverpool          1823.697
# Manchester City    1946.191
# Tottenham          1183.871
# Name: Pas3rd_season, dtype: float64

# %% [markdown]
# ### Top 2 passing playing more in the last 1/3

# %%
top4epl["PPA_season"]=top4epl.PPA*top4epl["90s"]
# Out:
# /var/folders/mf/7c7p544j17b4t3yzzvvx6hs80000gq/T/ipykernel_50964/229558691.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top4epl["PPA_season"]=top4epl.PPA*top4epl["90s"]

# %%
top4epl.groupby(by="Squad")["PPA_season"].sum()
# Out:
# Squad
# Chelsea            445.813
# Liverpool          528.238
# Manchester City    561.884
# Tottenham          357.861
# Name: PPA_season, dtype: float64

# %%
top4epl["CrsPA_season"]=top4epl.CrsPA*top4epl["90s"]
# Out:
# /var/folders/mf/7c7p544j17b4t3yzzvvx6hs80000gq/T/ipykernel_50964/3601025951.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top4epl["CrsPA_season"]=top4epl.CrsPA*top4epl["90s"]

# %%
top4epl.groupby(by="Squad")["CrsPA_season"].sum()
# Out:
# Squad
# Chelsea            69.087
# Liverpool          93.124
# Manchester City    77.830
# Tottenham          76.764
# Name: CrsPA_season, dtype: float64

# %%
top4epl["PasProg_season"]=top4epl.PasProg*top4epl["90s"]
# Out:
# /var/folders/mf/7c7p544j17b4t3yzzvvx6hs80000gq/T/ipykernel_50964/2898256782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top4epl["PasProg_season"]=top4epl.PasProg*top4epl["90s"]

# %%
top4epl.groupby(by="Squad")["PasProg_season"].sum()
# Out:
# Squad
# Chelsea            1614.232
# Liverpool          1966.867
# Manchester City    1766.320
# Tottenham          1318.238
# Name: PasProg_season, dtype: float64

# %%
top4epl["TB_season"]=top4epl.TB*top4epl["90s"]
# Out:
# /var/folders/mf/7c7p544j17b4t3yzzvvx6hs80000gq/T/ipykernel_50964/1451354554.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top4epl["TB_season"]=top4epl.TB*top4epl["90s"]

# %%
top4epl.groupby(by="Squad")["TB_season"].sum()
# Out:
# Squad
# Chelsea            60.772
# Liverpool          73.150
# Manchester City    63.794
# Tottenham          57.638
# Name: TB_season, dtype: float64

# %%
top4epl["Sw_season"]=top4epl.Sw*top4epl["90s"]
# Out:
# /var/folders/mf/7c7p544j17b4t3yzzvvx6hs80000gq/T/ipykernel_50964/3208017976.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top4epl["Sw_season"]=top4epl.Sw*top4epl["90s"]

# %%
top4epl.groupby(by="Squad")["Sw_season"].sum()
# Out:
# Squad
# Chelsea            454.355
# Liverpool          728.735
# Manchester City    730.300
# Tottenham          470.949
# Name: Sw_season, dtype: float64

# %%
top4epl["PasCrs_season"]=top4epl.PasCrs*top4epl["90s"]
# Out:
# /var/folders/mf/7c7p544j17b4t3yzzvvx6hs80000gq/T/ipykernel_50964/4266405223.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top4epl["PasCrs_season"]=top4epl.PasCrs*top4epl["90s"]

# %%
top4epl.groupby(by="Squad")["PasCrs_season"].sum()
# Out:
# Squad
# Chelsea            496.433
# Liverpool          554.343
# Manchester City    609.978
# Tottenham          406.786
# Name: PasCrs_season, dtype: float64

# %% [markdown]
# ### Liverpool & city cross alot

# %%
top4epl["CK_season"]=top4epl.CK*top4epl["90s"]
# Out:
# /var/folders/mf/7c7p544j17b4t3yzzvvx6hs80000gq/T/ipykernel_50964/683495623.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top4epl["CK_season"]=top4epl.CK*top4epl["90s"]

# %%
top4epl.groupby(by="Squad")["CK_season"].sum()
# Out:
# Squad
# Chelsea            241.068
# Liverpool          280.898
# Manchester City    314.865
# Tottenham          193.153
# Name: CK_season, dtype: float64

# %%
top4epl["PaswLeft_season"]=top4epl.PaswLeft*top4epl["90s"]
# Out:
# /var/folders/mf/7c7p544j17b4t3yzzvvx6hs80000gq/T/ipykernel_50964/1839516218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top4epl["PaswLeft_season"]=top4epl.PaswLeft*top4epl["90s"]

# %%
top4epl.groupby(by="Squad")["PaswLeft_season"].sum()
# Out:
# Squad
# Chelsea             5290.942
# Liverpool           5943.921
# Manchester City    10089.630
# Tottenham           5056.291
# Name: PaswLeft_season, dtype: float64

# %%
top4epl["PaswRight_season"]=top4epl.PaswRight*top4epl["90s"]
# Out:
# /var/folders/mf/7c7p544j17b4t3yzzvvx6hs80000gq/T/ipykernel_50964/3935630410.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top4epl["PaswRight_season"]=top4epl.PaswRight*top4epl["90s"]

# %%
top4epl.groupby(by="Squad")["PaswRight_season"].sum()
# Out:
# Squad
# Chelsea            16995.801
# Liverpool          16646.994
# Manchester City    15244.474
# Tottenham          13171.910
# Name: PaswRight_season, dtype: float64

# %% [markdown]
# ## Man city has more balance between left and right. Liverpool, chelsea & tottenham play more on the right.

# %%
top4epl["PaswHead_season"]=top4epl.PaswHead*top4epl["90s"]
# Out:
# /var/folders/mf/7c7p544j17b4t3yzzvvx6hs80000gq/T/ipykernel_50964/3354113253.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top4epl["PaswHead_season"]=top4epl.PaswHead*top4epl["90s"]

# %%
top4epl.groupby(by="Squad")["PaswHead_season"].sum()
# Out:
# Squad
# Chelsea            643.466
# Liverpool          840.478
# Manchester City    688.051
# Tottenham          628.974
# Name: PaswHead_season, dtype: float64

# %% [markdown]
# ### Liverpool heads a lot more than other team

# %%
top4epl["ScaDrib_season"]=top4epl.ScaDrib*top4epl["90s"]
# Out:
# /var/folders/mf/7c7p544j17b4t3yzzvvx6hs80000gq/T/ipykernel_50964/199172130.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top4epl["ScaDrib_season"]=top4epl.ScaDrib*top4epl["90s"]

# %%
top4epl.groupby(by="Squad")["ScaDrib_season"].sum()
# Out:
# Squad
# Chelsea            52.129
# Liverpool          70.172
# Manchester City    62.705
# Tottenham          41.117
# Name: ScaDrib_season, dtype: float64

# %% [markdown]
# ### Liverpool has good dribblers that create chances

# %%
top4epl["ScaFld_season"]=top4epl.ScaFld*top4epl["90s"]
# Out:
# /var/folders/mf/7c7p544j17b4t3yzzvvx6hs80000gq/T/ipykernel_50964/2509897267.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top4epl["ScaFld_season"]=top4epl.ScaFld*top4epl["90s"]

# %%
top4epl.groupby(by="Squad")["ScaFld_season"].sum()
# Out:
# Squad
# Chelsea            43.532
# Liverpool          37.263
# Manchester City    45.965
# Tottenham          35.272
# Name: ScaFld_season, dtype: float64

# %% [markdown]
# ### Man city won a lot of fouls in dangerous area

# %%
top4epl["ScaDef_season"]=top4epl.ScaDef*top4epl["90s"]
# Out:
# /var/folders/mf/7c7p544j17b4t3yzzvvx6hs80000gq/T/ipykernel_50964/3633453201.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top4epl["ScaDef_season"]=top4epl.ScaDef*top4epl["90s"]

# %%
top4epl.groupby(by="Squad")["ScaDef_season"].sum()
# Out:
# Squad
# Chelsea            18.785
# Liverpool          24.879
# Manchester City    13.138
# Tottenham          12.084
# Name: ScaDef_season, dtype: float64

# %% [markdown]
# ### Chelsea and liverpool are dangerous on the counter

# %%
top4epl["GCA_season"]=top4epl["GCA"]*top4epl["90s"]
# Out:
# /var/folders/mf/7c7p544j17b4t3yzzvvx6hs80000gq/T/ipykernel_50964/2188812521.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top4epl["GCA_season"]=top4epl["GCA"]*top4epl["90s"]

# %%
top4epl[top4epl.Squad=="Liverpool"]["GCA_season"]
# Out:
# 56       5.950
# 62      17.118
# 65       1.080
# 710      4.028
# 718      6.120
# 812      0.988
# 843      4.883
# 893      6.050
# 1022     1.998
# 1041     0.000
# 1154    10.982
# 1290     1.995
# 1302    13.939
# 1361     5.980
# 1363     0.000
# 1410     1.980
# 1640    13.146
# 1706     8.990
# 1798     1.045
# 1801     1.008
# 1848     0.000
# 1999     1.995
# 2017     0.957
# 2275    16.074
# 2360    24.867
# 2713     3.007
# 2842     2.000
# Name: GCA_season, dtype: float64

# %%
top4epl.groupby(by="Squad").GCA_season.sum()
# Out:
# Squad
# Chelsea            124.036
# Liverpool          156.180
# Manchester City    142.001
# Tottenham          113.902
# Name: GCA_season, dtype: float64

# %%
top4epl.loc[:,["GCA","Min","Squad"]]
# Out:
#         GCA   Min            Squad
# 40     0.00   923  Manchester City
# 56     0.35  1534        Liverpool
# 62     0.54  2853        Liverpool
# 65     0.03  3240        Liverpool
# 69     0.14   657        Tottenham
# ...     ...   ...              ...
# 2834   0.28  1283          Chelsea
# 2842  20.00     8        Liverpool
# 2849   0.40   912        Tottenham
# 2907   0.86  1047  Manchester City
# 2908   0.48  1319          Chelsea
#
# [104 rows x 3 columns]

# %%
top4epl["GCA_Min"] = top4epl.GCA*top4epl.Min
# Out:
# /var/folders/mf/7c7p544j17b4t3yzzvvx6hs80000gq/T/ipykernel_50964/1868253912.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top4epl["GCA_Min"] = top4epl.GCA*top4epl.Min

# %%
top4epl.groupby(by = "Squad").GCA_Min.sum()
# Out:
# Squad
# Chelsea            11160.71
# Liverpool          14033.30
# Manchester City    12779.69
# Tottenham          10260.47
# Name: GCA_Min, dtype: float64

# %%
top4epl[top4epl.GCA_Min>0].groupby(by="Squad").GCA_Min.count()
# Out:
# Squad
# Chelsea            21
# Liverpool          24
# Manchester City    18
# Tottenham          21
# Name: GCA_Min, dtype: int64

# %%
top4epl["GCA_season"]=top4epl.GCA*top4epl["90s"]
# Out:
# /var/folders/mf/7c7p544j17b4t3yzzvvx6hs80000gq/T/ipykernel_50964/870493742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top4epl["GCA_season"]=top4epl.GCA*top4epl["90s"]

# %%
top4epl.sort_values(by = ["GCA_season"],ascending = False).head(10)
# Out:
#         Rk                  Player Nation   Pos            Squad  \
# 2360  2361           Mohamed Salah    EGY    FW        Liverpool
# 1342  1343              Harry Kane    ENG    FW        Tottenham
# 1280  1281           Gabriel Jesus    BRA    FW  Manchester City
# 62      63  Trent Alexander-Arnold    ENG    DF        Liverpool
# 450    451            João Cancelo    POR    DF  Manchester City
# 2275  2276        Andrew Robertson    SCO    DF        Liverpool
# 1180  1181           Son Heung-min    KOR  FWMF        Tottenham
# 1859  1860             Mason Mount    ENG  MFFW          Chelsea
# 1445  1446        Dejan Kulusevski    SWE  MFFW        Tottenham
# 646    647         Kevin De Bruyne    BEL    MF  Manchester City
#
#                 Comp   Age  Born  MP  Starts  ...  PKwon  PKcon   OG  Recov  \
# 2360  Premier League  29.0  1992  35      30  ...   0.07    0.0  0.0   5.73
# 1342  Premier League  28.0  1993  37      36  ...   0.00    0.0  0.0   4.18
# ...
